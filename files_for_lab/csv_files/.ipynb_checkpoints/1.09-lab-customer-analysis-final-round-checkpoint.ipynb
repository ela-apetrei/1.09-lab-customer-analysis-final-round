# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import pickle as pkl

import warnings
warnings.filterwarnings('ignore') ### 02 - Getting Data

# %% [markdown]
# ### 01 - Problem (case study)
# - Data Description.
# - Goal.

# %% [markdown]
# ### 02 - Getting Data
# - Read the `.csv` file.

# %%
data = pd.read_csv('marketing_customer_analysis.csv')
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# ### 03 - Cleaning/Wrangling/EDA
#
# - Change headers names.
# - Deal with NaN values.
# - Categorical Features.
# - Numerical Features.
# - Exploration.

# %%
#lower cases
data.columns = data.columns.str.lower()
data
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  ...  \
# ...

# %%
# standardized column names will be meaninfull strings, lower cased and with '_' instead of 'spaces'
data.columns = [data.columns[i].lower().replace(' ', '_') for i in range(len(data.columns)) ]
 
data
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
# renaming columns
data = data.rename(columns={'unnamed:_0':'id'})
data
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
data = data.set_index('customer')

# %%
#checking NaN values
data.isnull().values.any()
# Out:
# False

# %%
data
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
# ...

# %%
categorical = data.select_dtypes(include='object')
categorical
# Out:
#                state response  coverage education effective_to_date  \
# customer
# BU79786   Washington       No     Basic  Bachelor           2/24/11
# QZ44356      Arizona       No  Extended  Bachelor           1/31/11
# AI49188       Nevada       No   Premium  Bachelor           2/19/11
# WW63253   California       No     Basic  Bachelor           1/20/11
# HB64268   Washington       No     Basic  Bachelor            2/3/11
# ...              ...      ...       ...       ...               ...
# LA72316   California       No     Basic  Bachelor           2/10/11
# PK87824   California      Yes  Extended   College           2/12/11
# TD14365   California       No  Extended  Bachelor            2/6/11
# UP19263   California       No  Extended   College            2/3/11
# Y167826   California       No  Extended   College           2/14/11
#
#          employmentstatus gender location_code marital_status     policy_type  \
# customer
# ...

# %%
# Checking if parametrization is needed
## for column in categorical.columns:
#print(column, categorical[column].unique())

# %%
numerical = data.select_dtypes(include='number')
numerical
# Out:
#           customer_lifetime_value  income  monthly_premium_auto  \
# customer
# BU79786               2763.519279   56274                    69
# QZ44356               6979.535903       0                    94
# AI49188              12887.431650   48767                   108
# WW63253               7645.861827       0                   106
# HB64268               2813.692575   43836                    73
# ...                           ...     ...                   ...
# LA72316              23405.987980   71941                    73
# PK87824               3096.511217   21604                    79
# TD14365               8163.890428       0                    85
# UP19263               7524.442436   21941                    96
# Y167826               2611.836866       0                    77
#
#           months_since_last_claim  months_since_policy_inception  \
# customer
# BU79786                        32                              5
# ...

# %%
data.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# ...

# %% [markdown]
# ### 04 - Processing Data
#
# - Dealing with outliers.
# - Normalization.
# - Encoding Categorical Data.
# - Splitting into train set and test set.

# %%
#visualizing the data
for column in data.select_dtypes(np.number).columns:
    sns.distplot(data[column])
    plt.show()

# %%
#dropping the outliers
def remove_outliers(data, threshold=1.5, in_columns=data.select_dtypes(np.number).columns, skip_columns=[]):
    for column in in_columns:
        if column not in skip_columns:
            upper = np.percentile(data[column],75)
            lower = np.percentile(data[column],25)
            iqr = upper - lower
            upper_limit = upper + threshold * iqr
            lower_limit = lower - threshold * iqr
            data = data[(data[column]>lower_limit) & (data[column]<upper_limit)]
    return data

# %%
data = remove_outliers(data, threshold=1.5, in_columns=['total_claim_amount', 'customer_lifetime_value'])
data
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# OC83172       Oregon              8256.297800      Yes     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# YM19146   California              4100.398533       No   Premium   College
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
# ...

# %%
## X-y defining;
X = data.drop('total_claim_amount', axis=1)
y = data['total_claim_amount']

# %%
## X-y split for Normalizer;
X_num = X.select_dtypes(include = np.number)
X_cat = X.select_dtypes(include = np.object)

X_num
# Out:
#           customer_lifetime_value  income  monthly_premium_auto  \
# customer
# BU79786               2763.519279   56274                    69
# AI49188              12887.431650   48767                   108
# WW63253               7645.861827       0                   106
# HB64268               2813.692575   43836                    73
# OC83172               8256.297800   62902                    69
# ...                           ...     ...                   ...
# YM19146               4100.398533   47761                   104
# PK87824               3096.511217   21604                    79
# TD14365               8163.890428       0                    85
# UP19263               7524.442436   21941                    96
# Y167826               2611.836866       0                    77
#
#           months_since_last_claim  months_since_policy_inception  \
# customer
# BU79786                        32                              5
# ...

# %%
#Encoding
encoder = OneHotEncoder(handle_unknown='error', drop='first')
encoder.fit(X_cat)
# Out:
# OneHotEncoder(drop='first')

# %%
#assigning the encoded values of categorical columns to x_cat
x_cat = encoder.transform(X_cat).toarray()

# %%
# getting the column names
cols = list(X_num.columns)
cols.extend(list([g for i in encoder.categories_ for g in i[1:]]))

# %%
cols
# Out:
# ['customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'California',
#  'Nevada',
#  'Oregon',
#  'Washington',
#  'Yes',
#  'Extended',
#  'Premium',
#  'College',
#  'Doctor',
#  'High School or Below',
#  'Master',
#  '1/10/11',
#  '1/11/11',
#  '1/12/11',
#  '1/13/11',
#  '1/14/11',
#  '1/15/11',
#  '1/16/11',
#  '1/17/11',
#  '1/18/11',
#  '1/19/11',
#  '1/2/11',
#  '1/20/11',
#  '1/21/11',
#  '1/22/11',
#  '1/23/11',
#  '1/24/11',
#  '1/25/11',
#  '1/26/11',
#  '1/27/11',
#  '1/28/11',
#  '1/29/11',
#  '1/3/11',
#  '1/30/11',
#  '1/31/11',
#  '1/4/11',
#  '1/5/11',
#  '1/6/11',
#  '1/7/11',
#  '1/8/11',
#  '1/9/11',
#  '2/1/11',
#  '2/10/11',
#  '2/11/11',
#  '2/12/11',
#  '2/13/11',
#  '2/14/11',
#  '2/15/11',
#  '2/16/11',
#  '2/17/11',
#  '2/18/11',
#  '2/19/11',
#  '2/2/11',
#  '2/20/11',
#  '2/21/11',
#  '2/22/11',
#  '2/23/11',
# ...

# %%
# Normalize (numerical).
transformer = Normalizer()
transformer.fit(X_num)

with open('transformer.pkl', 'wb') as file:
    pkl.dump(transformer, file)

with open('transformer.pkl', 'rb') as file:
    transformer = pkl.load(file)

x_normalized = transformer.transform(X_num)
#pd.DataFrame(x_normalized)
x_normalized.shape
# Out:
# (7742, 7)

# %%
#concatenate x_
x = np.concatenate([x_normalized, x_cat], axis = 1)

# %%
# train-test split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### 05 - Modeling
#
# - Apply model.

# %%
# start the model
model = LinearRegression()
# train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 06 - Model Validation
#
# - R2.
# - MSE.
# - RMSE.
# - MAE.

# %%
# get predictions
predictions = model.predict(X_test)

# %%
# get metrics
r2_score(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False)
# Out:
# (0.7726787408621616, 73.03645808744957, 95.46899081782412)

# %%
import math

results = pd.DataFrame()
results['true'] = y_test
results['pred'] = predictions
results['resid']= results.apply(lambda x: abs(x['true'] - x['pred']), axis=1)
results
# Out:
#                 true        pred       resid
# customer
# XJ40322   120.128737   79.788310   40.340427
# KI75855   392.235698  365.288310   26.947388
# KP54476   495.612777  489.610005    6.002772
# EY27917   192.265438  194.478908    2.213470
# WM19996   487.273964  385.724202  101.549762
# ...              ...         ...         ...
# IS75141   160.825045   23.038310  137.786735
# QE13586   384.000000  443.538310   59.538310
# MY89889   355.200000  499.288310  144.088310
# ZM92052    67.859881   54.788310   13.071571
# VI55112   214.247114  319.981687  105.734573
#
# [2323 rows x 3 columns]

# %%
results.sort_values('resid', ascending=False).head(50)
# Out:
#                 true        pred       resid
# customer
# XI14610   915.188647  464.288310  450.900337
# NB10500   882.871945  460.788310  422.083635
# HG65722     0.517753  422.288310  421.770557
# PP92749   882.871945  467.538310  415.333635
# IS85460   810.461707  402.030948  408.430759
# PJ73790   882.871945  477.163310  405.708635
# RE36747   874.324338  482.788310  391.536028
# VO78441   871.505797  502.788310  368.717487
# JV38934   768.797656  402.788310  366.009346
# EC44438   724.463534  362.538310  361.925224
# YH60476   787.993313  429.310724  358.682589
# GX32768   807.279979  449.325759  357.954220
# IK77998   851.022089  498.288310  352.733779
# HI58196   897.379535  546.538310  350.841225
# LM54297   806.534801  457.288310  349.246491
# JG36165   904.385726  557.338449  347.047277
# UX24010   725.849253  382.036956  343.812297
# VC77127   837.438442  497.288310  340.150132
# LR69185   848.201438  511.038310  337.163128
# HY76810   141.460349  477.706349  336.246000
# ...

# %%
results.describe()
# Out:
#               true         pred        resid
# count  2323.000000  2323.000000  2323.000000
# mean    377.935604   377.197087    73.036458
# std     200.279179   179.462640    61.494975
# min       0.517753   -15.853235     0.061690
# 25%     244.433129   250.038310    28.970101
# 50%     355.200000   404.538310    59.388310
# 75%     508.658946   498.749166   100.344457
# max     915.188647   796.288310   450.900337

# %%
sns.regplot(results['true'], results['pred'])
# Out:
# <AxesSubplot:xlabel='true', ylabel='pred'>

# %%
data['income'].corr(data['total_claim_amount'])
# Out:
# -0.37112752606609106

# %%
len(data.index), len(data.index.unique())
# Out:
# (7742, 7742)
